# %%
import numpy as np
import pandas as pd

# %%
housing=pd.read_csv("C:/Users/ws_htu118/Documents/train.csv")

# %%
housing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
housing.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
#Checking for NULL VALUES 
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
#Checking null columns 
null_column=housing.isnull().sum()
null_column=null_column[null_column>0]

# %%
round(null_column*100/1460,2)
# Out:
# LotFrontage     17.74
# Alley           93.77
# MasVnrType       0.55
# MasVnrArea       0.55
# BsmtQual         2.53
# BsmtCond         2.53
# BsmtExposure     2.60
# BsmtFinType1     2.53
# BsmtFinType2     2.60
# Electrical       0.07
# FireplaceQu     47.26
# GarageType       5.55
# GarageYrBlt      5.55
# GarageFinish     5.55
# GarageQual       5.55
# GarageCond       5.55
# PoolQC          99.52
# Fence           80.75
# MiscFeature     96.30
# dtype: float64

# %%
##Removing null values with highest percentage
filter_null_column=["LotFrontage","Alley","FireplaceQu","PoolQC","Fence","MiscFeature"]
housing.drop(filter_null_column, axis=1, inplace = True)

# %%
housing.shape
# Out:
# (1460, 75)

# %%
#Droping unique Id field
housing.drop("Id",axis=1,inplace=True)

# %%
housing
# Out:
#       MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0             60       RL     8450   Pave      Reg         Lvl    AllPub
# 1             20       RL     9600   Pave      Reg         Lvl    AllPub
# 2             60       RL    11250   Pave      IR1         Lvl    AllPub
# 3             70       RL     9550   Pave      IR1         Lvl    AllPub
# 4             60       RL    14260   Pave      IR1         Lvl    AllPub
# ...          ...      ...      ...    ...      ...         ...       ...
# 1455          60       RL     7917   Pave      Reg         Lvl    AllPub
# 1456          20       RL    13175   Pave      Reg         Lvl    AllPub
# 1457          70       RL     9042   Pave      Reg         Lvl    AllPub
# 1458          20       RL     9717   Pave      Reg         Lvl    AllPub
# 1459          20       RL     9937   Pave      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... EnclosedPorch 3SsnPorch  \
# ...

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 74 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotArea        1460 non-null   int64
#  3   Street         1460 non-null   object
#  4   LotShape       1460 non-null   object
#  5   LandContour    1460 non-null   object
#  6   Utilities      1460 non-null   object
#  7   LotConfig      1460 non-null   object
#  8   LandSlope      1460 non-null   object
#  9   Neighborhood   1460 non-null   object
#  10  Condition1     1460 non-null   object
#  11  Condition2     1460 non-null   object
#  12  BldgType       1460 non-null   object
#  13  HouseStyle     1460 non-null   object
#  14  OverallQual    1460 non-null   int64
#  15  OverallCond    1460 non-null   int64
#  16  YearBuilt      1460 non-null   int64
# ...

# %%
null_column=housing.isnull().sum()
null_column=null_column[null_column>0]

# %%
#Check percentage of null/missing values

round(null_column*100/1460,2)
# Out:
# MasVnrType      0.55
# MasVnrArea      0.55
# BsmtQual        2.53
# BsmtCond        2.53
# BsmtExposure    2.60
# BsmtFinType1    2.53
# BsmtFinType2    2.60
# Electrical      0.07
# GarageType      5.55
# GarageYrBlt     5.55
# GarageFinish    5.55
# GarageQual      5.55
# GarageCond      5.55
# dtype: float64

# %%
housing['YearBuilt'].max()
# Out:
# 2010

# %%
def fill_missing_values(df):
     null_column_list = df.isnull().sum()
     null_column_list = null_column_list[null_column_list>0]
     for col in null_column_list.index:
        if df[col].dtype.name == 'object':
            # impute mode
             df[col].fillna(df[col].mode()[0], inplace=True)
       
        
        elif df[col].dtype.name == 'float64' or df[col].dtype.name == 'int64' or df[col].dtype.name == 'int32':
            # impute median
            df[col] = df[col].fillna((df[col].median()))
     return df

# %%
#Fill all missing values with mode and median based on data type
housing=fill_missing_values(housing)

# %%
##Check if missing values are done
housing.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 74, dtype: int64

# %%
# Converting years to age
housing['YearBuilt_Age'] = housing['YearBuilt'].max() - housing['YearBuilt']
housing['YearRemodAdd_Age'] = housing['YearRemodAdd'].max() - housing['YearRemodAdd']
housing['YrSold_Age'] = housing['YrSold'].max() - housing['YrSold']
housing['GarageYrBlt_Age'] = housing['GarageYrBlt'].max() - housing['GarageYrBlt']

# %%
# Dropping columns
housing.drop(['YearBuilt','YearRemodAdd','YrSold','GarageYrBlt'], axis=1, inplace = True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing[['YearBuilt_Age','YearRemodAdd_Age','YrSold_Age','GarageYrBlt_Age']].head(10)
# Out:
#    YearBuilt_Age  YearRemodAdd_Age  YrSold_Age  GarageYrBlt_Age
# 0              7                 7           2              7.0
# 1             34                34           3             34.0
# 2              9                 8           2              9.0
# 3             95                40           4             12.0
# 4             10                10           2             10.0
# 5             17                15           1             17.0
# 6              6                 5           3              6.0
# 7             37                37           1             37.0
# 8             79                60           2             79.0
# 9             71                60           2             71.0

# %%
plt.subplots(figsize=(30, 30))
sns.heatmap(housing.corr(),annot= True)
# Out:
# <AxesSubplot:>

# %%
corr_val = housing[list(housing.dtypes[housing.dtypes != 'object'].index)].corr()

# %%
corr_coef = corr_val[corr_val['SalePrice'] > 0.5]['SalePrice']

# %%
corr_coef_cols = [idx for idx in corr_coef.index]

# %%
corr_coef_cols
# Out:
# ['OverallQual',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'SalePrice']

# %%
#Clearly indicate that there is salesPrice parameter which are linearly dependent on some of these independent parameter
sns.pairplot(housing, x_vars=corr_coef_cols[1:-1], y_vars=[corr_coef_cols[-1]], kind="reg" )
plt.show()

# %%
housing.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood  ... PoolArea MiscVal MoSold SaleType  \
# 0    Inside       Gtl      CollgCr  ...        0       0      2       WD
# 1       FR2       Gtl      Veenker  ...        0       0      5       WD
# 2    Inside       Gtl      CollgCr  ...        0       0      9       WD
# 3    Corner       Gtl      Crawfor  ...        0       0      2       WD
# 4       FR2       Gtl      NoRidge  ...        0       0     12       WD
#
#    SaleCondition  SalePrice YearBuilt_Age YearRemodAdd_Age YrSold_Age  \
# ...

# %%
cat_col_list=["MSZoning","Street","LotShape","LandContour","Utilities","LotConfig","LandSlope","Neighborhood","SaleType","SaleCondition","ExterQual","ExterCond","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","BsmtFinType2","HeatingQC","1stFlrSF","KitchenQual","GarageFinish","GarageQual","GarageCond","GarageCond","CentralAir"]

# %%
def label_encoding(colNames):
    for colName in colNames:
        unique_vals = housing[colName].unique()
        map_vals = {}
        for idx, val in enumerate(unique_vals):
            map_vals[val] = idx
        housing[colName] = housing[colName].map(map_vals)

# %%
label_encoding(cat_col_list)
housing
# Out:
#       MSSubClass  MSZoning  LotArea  Street  LotShape  LandContour  Utilities  \
# 0             60         0     8450       0         0            0          0
# 1             20         0     9600       0         0            0          0
# 2             60         0    11250       0         1            0          0
# 3             70         0     9550       0         1            0          0
# 4             60         0    14260       0         1            0          0
# ...          ...       ...      ...     ...       ...          ...        ...
# 1455          60         0     7917       0         0            0          0
# 1456          20         0    13175       0         0            0          0
# 1457          70         0     9042       0         0            0          0
# 1458          20         0     9717       0         0            0          0
# 1459          20         0     9937       0         0            0          0
#
# ...

# %%
#Creating Dummy Column for categorical variable
dummy_col_names = ['MSZoning','LandContour','LotConfig','Neighborhood','Condition1','Condition2','BldgType',
             'HouseStyle','RoofStyle','RoofMatl','Exterior1st', 'Exterior2nd','MasVnrType','Foundation',
             'Heating','Electrical','Functional','GarageType','PavedDrive','SaleType','SaleCondition']
dummies = pd.get_dummies(housing[dummy_col_names], drop_first = True)
housing = pd.concat([housing, dummies], axis = 1)
housing.drop(dummy_col_names, axis = 1, inplace = True)

# %%
housing.head(10)
# Out:
#    MSSubClass  LotArea  Street  LotShape  Utilities  LandSlope  OverallQual  \
# 0          60     8450       0         0          0          0            7
# 1          20     9600       0         0          0          0            6
# 2          60    11250       0         1          0          0            7
# 3          70     9550       0         1          0          0            7
# 4          60    14260       0         1          0          0            8
# 5          50    14115       0         1          0          0            5
# 6          20    10084       0         0          0          0            8
# 7          60    10382       0         1          0          0            7
# 8          50     6120       0         0          0          0            7
# 9         190     7420       0         0          0          0            5
#
#    OverallCond  MasVnrArea  ExterQual  ...  Functional_Mod  Functional_Sev  \
# ...

# %%
housing.shape
# Out:
# (1460, 150)

# %%
housing.describe()
# Out:
#         MSSubClass        LotArea       Street     LotShape    Utilities  \
# count  1460.000000    1460.000000  1460.000000  1460.000000  1460.000000
# mean     56.897260   10516.828082     0.004110     0.408219     0.000685
# std      42.300571    9981.264932     0.063996     0.582296     0.026171
# min      20.000000    1300.000000     0.000000     0.000000     0.000000
# 25%      20.000000    7553.500000     0.000000     0.000000     0.000000
# 50%      50.000000    9478.500000     0.000000     0.000000     0.000000
# 75%      70.000000   11601.500000     0.000000     1.000000     0.000000
# max     190.000000  215245.000000     1.000000     3.000000     1.000000
#
#          LandSlope  OverallQual  OverallCond   MasVnrArea    ExterQual  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean      0.062329     6.099315     5.575342   103.117123     0.720548  ...
# std       0.276232     1.382997     1.112799   180.731373     0.574763  ...
# ...

# %%
housing.head()
# Out:
#    MSSubClass  LotArea  Street  LotShape  Utilities  LandSlope  OverallQual  \
# 0          60     8450       0         0          0          0            7
# 1          20     9600       0         0          0          0            6
# 2          60    11250       0         1          0          0            7
# 3          70     9550       0         1          0          0            7
# 4          60    14260       0         1          0          0            8
#
#    OverallCond  MasVnrArea  ExterQual  ...  Functional_Mod  Functional_Sev  \
# 0            5       196.0          0  ...               0               0
# 1            8         0.0          1  ...               0               0
# 2            5       162.0          0  ...               0               0
# 3            5         0.0          1  ...               0               0
# 4            5       350.0          0  ...               0               0
#
# ...

# %%
import sklearn
import sklearn.metrics as metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso, Ridge
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

from sklearn.feature_selection import RFE

# %%
df_train, df_test = train_test_split(housing, train_size=0.7, test_size=0.3, random_state=100)

# %%
df_train
# Out:
#       MSSubClass  LotArea  Street  LotShape  Utilities  LandSlope  \
# 210           30     5604       0         0          0          0
# 318           60     9900       0         0          0          1
# 239           50     8741       0         0          0          0
# 986           50     5310       0         0          0          0
# 1416         190    11340       0         0          0          0
# ...          ...      ...     ...       ...        ...        ...
# 1009          50     6000       0         0          0          0
# 802           60     8199       0         0          0          0
# 53            20    50271       0         1          0          0
# 350          120     7820       0         1          0          0
# 79            50    10440       0         0          0          0
#
#       OverallQual  OverallCond  MasVnrArea  ExterQual  ...  Functional_Mod  \
# 210             5            6         0.0          1  ...               0
# ...

# %%
scaler_col = ['MSSubClass','LotArea','OverallQual','OverallCond', 'MasVnrArea','BsmtFinSF1',
              'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF', 'LowQualFinSF',
              'GrLivArea','BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr',
              'KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageCars','GarageArea','WoodDeckSF',
              'OpenPorchSF','EnclosedPorch','3SsnPorch', 'ScreenPorch','PoolArea','MiscVal','SalePrice']

scaler = StandardScaler()
df_train[scaler_col] = scaler.fit_transform(df_train[scaler_col])
df_test[scaler_col] = scaler.transform(df_test[scaler_col])

# %%
df_train.head()
# Out:
#       MSSubClass   LotArea  Street  LotShape  Utilities  LandSlope  \
# 210    -0.657071 -0.473765       0         0          0          0
# 318     0.035976 -0.056845       0         0          0          1
# 239    -0.195040 -0.169324       0         0          0          0
# 986    -0.195040 -0.502297       0         0          0          0
# 1416    3.039179  0.082905       0         0          0          0
#
#       OverallQual  OverallCond  MasVnrArea  ExterQual  ...  Functional_Mod  \
# 210     -0.779861     0.383154   -0.558025          1  ...               0
# 318      0.649651    -0.533005    0.809137          0  ...               0
# 239     -0.065105    -1.449164   -0.558025          1  ...               0
# 986     -0.065105     2.215472   -0.558025          1  ...               0
# 1416    -1.494617     0.383154   -0.558025          1  ...               0
#
#       Functional_Sev  Functional_Typ  GarageType_Attchd  GarageType_Basment  \
# ...

# %%
# Let us check if the target variable is normal in both train and test dataset
plt.figure(figsize=(16,6))
plt.subplot(121)
sns.distplot(df_train.SalePrice)
plt.subplot(122)
sns.distplot(df_test.SalePrice)
# Out:
# C:\Users\ws_htu118\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ws_htu118\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
# Create X and y
y_train = df_train.pop('SalePrice')
X_train = df_train

y_test = df_test.pop('SalePrice')
X_test = df_test

# %%
# RFE
lm  = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm,n_features_to_select=50)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=50)

# %%
rfe_scores = pd.DataFrame(list(zip(X_train.columns,rfe.support_,rfe.ranking_)))

# %%
rfe_scores
# Out:
#                       0      1   2
# 0            MSSubClass  False  92
# 1               LotArea   True   1
# 2                Street  False  17
# 3              LotShape  False  86
# 4             Utilities  False  52
# ..                  ...    ...  ..
# 144  GarageType_BuiltIn   True   1
# 145  GarageType_CarPort  False  53
# 146   GarageType_Detchd  False  56
# 147        PavedDrive_P  False  77
# 148        PavedDrive_Y  False  34
#
# [149 rows x 3 columns]

# %%
col = X_train.columns[rfe.support_]

# %%
col
# Out:
# Index(['LotArea', 'OverallQual', 'BsmtQual', 'BsmtFinSF1', 'TotalBsmtSF',
#        'GrLivArea', 'BedroomAbvGr', 'KitchenQual', 'GarageArea',
#        'Condition1_Norm', 'Condition2_PosN', 'Condition2_RRAe',
#        'BldgType_Duplex', 'BldgType_TwnhsE', 'HouseStyle_2.5Fin',
#        'HouseStyle_2.5Unf', 'HouseStyle_SFoyer', 'RoofStyle_Gambrel',
#        'RoofMatl_CompShg', 'RoofMatl_Membran', 'RoofMatl_Metal',
#        'RoofMatl_Roll', 'RoofMatl_Tar&Grv', 'RoofMatl_WdShake',
#        'RoofMatl_WdShngl', 'Exterior1st_AsphShn', 'Exterior1st_BrkComm',
#        'Exterior1st_CBlock', 'Exterior1st_CemntBd', 'Exterior1st_ImStucc',
#        'Exterior1st_Plywood', 'Exterior1st_Stone', 'Exterior2nd_AsphShn',
#        'Exterior2nd_CBlock', 'Exterior2nd_CmentBd', 'Exterior2nd_Stone',
#        'Exterior2nd_Wd Sdng', 'Foundation_PConc', 'Foundation_Slab',
#        'Heating_GasA', 'Heating_GasW', 'Heating_Grav', 'Heating_OthW',
#        'Heating_Wall', 'Electrical_FuseP', 'Functional_Min1',
# ...

# %%
X_train = X_train[col]
X_test = X_test[col]

# %%
    lm = Lasso(alpha=0.001)
    lm.fit(X_train,y_train)

    # train score
    y_train_pred = lm.predict(X_train)
    print("Train_dataset:",metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

    # test score
    y_test_pred  = lm.predict(X_test)
    print("Test_dataset:",metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# Train_dataset: 0.8200228933214385
# Test_dataset: 0.8006991759400758

# %%
# Gridsearch Operation on Training data set
# Objective - Find optimal value of alpha

folds = KFold(n_splits=10,shuffle=True,random_state=100)

hyper_param = {'alpha':[0.001, 0.01, 0.1,1.0, 5.0, 10.0,20.0]}

model = Lasso()

model_cv = GridSearchCV(estimator = model,
                        param_grid=hyper_param,
                        scoring='r2',
                        cv=folds,
                        verbose=1,
                        return_train_score=True
                       )

model_cv.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=100, shuffle=True),
#              estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 5.0, 10.0, 20.0]},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
cv_result_train_lasso = pd.DataFrame(model_cv.cv_results_)
cv_result_train_lasso['param_alpha'] = cv_result_train_lasso['param_alpha'].astype('float32')
cv_result_train_lasso.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.011378      0.003340         0.006703        0.002441        0.001
# 1       0.012783      0.003184         0.006272        0.002719        0.010
# 2       0.010757      0.003296         0.005788        0.001609        0.100
# 3       0.009640      0.002751         0.005578        0.001655        1.000
# 4       0.009672      0.003839         0.004953        0.000847        5.000
#
#              params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.001}           0.869275           0.276559           0.839949
# 1   {'alpha': 0.01}           0.852091           0.386632           0.840162
# 2    {'alpha': 0.1}           0.797076           0.493021           0.787733
# 3    {'alpha': 1.0}          -0.010958          -0.010191          -0.000095
# 4    {'alpha': 5.0}          -0.010958          -0.010191          -0.000095
#
# ...

# %%
def r2_score(cv_result, is_log=False):
    plt.figure(figsize=(12,6))
    plt.plot(cv_result['param_alpha'], cv_result['mean_train_score'])
    plt.plot(cv_result['param_alpha'], cv_result['mean_test_score'])
    if is_log == True:
        plt.xscale('log')
    plt.ylabel('R2 Score')
    plt.xlabel('Alpha')
    plt.show()

# %%
r2_score(cv_result_train_lasso, True)

# %%
print('For Lasso, the Best Alpha value = ', model_cv.best_params_['alpha'])
# Out:
# For Lasso, the Best Alpha value =  0.01

# %%
# Now that we have optimal value of alpha = 0.01, we can use this alpha to run the model again
#Lasso
lm = Lasso(alpha=0.01)
lm.fit(X_train,y_train)

# train score
y_train_pred = lm.predict(X_train)
print(metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

# test score
y_test_pred  = lm.predict(X_test)
print(metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# 0.7758250990657451
# 0.8090417135990562

# %%
#Ridge
ridge = Ridge(alpha=0.01)
ridge.fit(X_train,y_train)

# train score
y_train_pred = ridge.predict(X_train)
print(metrics.r2_score(y_train, y_train_pred))

# test score
y_test_pred = ridge.predict(X_test)
print(metrics.r2_score(y_test, y_test_pred))
# Out:
# 0.8879693517948712
# 0.7640806881932638

# %%
# Gridsearch Operation on Training data set
# Objective - Find optimal value of alpha

folds = KFold(n_splits=10,shuffle=True,random_state=100)

hyper_param = {'alpha':[0.001, 0.01, 0.1,1.0, 5.0, 10.0,20.0]}

model = Ridge()

model_cv = GridSearchCV(estimator = model,
                        param_grid=hyper_param,
                        scoring='r2',
                        cv=folds,
                        verbose=1,
                        return_train_score=True
                       )

model_cv.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=100, shuffle=True),
#              estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 5.0, 10.0, 20.0]},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
cv_result_train_ridge = pd.DataFrame(model_cv.cv_results_)
cv_result_train_ridge['param_alpha'] = cv_result_train_lasso['param_alpha'].astype('float32')
cv_result_train_ridge.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.012761      0.007036         0.006805        0.005510        0.001
# 1       0.013334      0.005091         0.009349        0.005059        0.010
# 2       0.008451      0.002475         0.005311        0.002227        0.100
# 3       0.007957      0.003625         0.005883        0.003082        1.000
# 4       0.016285      0.008675         0.011340        0.005277        5.000
#
#              params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.001}           0.889223           0.201611           0.802581
# 1   {'alpha': 0.01}           0.889444           0.203330           0.805797
# 2    {'alpha': 0.1}           0.884169           0.218308           0.819147
# 3    {'alpha': 1.0}           0.866496           0.284978           0.831851
# 4    {'alpha': 5.0}           0.859942           0.336737           0.839035
#
# ...

# %%
r2_score(cv_result_train_ridge, True)

# %%
print('For Ridge, the Best Alpha value = ', model_cv.best_params_['alpha'])
# Out:
# For Ridge, the Best Alpha value =  20.0

# %%
# Now that we have optimal value of alpha = 20, we can use this alpha to run the model again
#Ridge
ridge = Ridge(alpha=20)
ridge.fit(X_train,y_train)

# train score
y_train_pred = ridge.predict(X_train)
print(metrics.r2_score(y_train, y_train_pred))

# test score
y_test_pred = ridge.predict(X_test)
print(metrics.r2_score(y_test, y_test_pred))
# Out:
# 0.7884357465855563
# 0.8226139457786548

# %%
# ridge coefficients
model_parameter = list(ridge.coef_)
model_parameter.insert(0,ridge.intercept_)
model_parameter = [round(x,3) for x in model_parameter]
col = X_train.columns
col = col.insert(0,'Constant')
list(zip(col,model_parameter))
# Out:
# [('Constant', -0.601),
#  ('LotArea', 0.067),
#  ('OverallQual', 0.387),
#  ('BsmtQual', 0.096),
#  ('BsmtFinSF1', 0.088),
#  ('TotalBsmtSF', 0.097),
#  ('GrLivArea', 0.315),
#  ('BedroomAbvGr', -0.038),
#  ('KitchenQual', 0.038),
#  ('GarageArea', 0.131),
#  ('Condition1_Norm', 0.206),
#  ('Condition2_PosN', -0.209),
#  ('Condition2_RRAe', -0.004),
#  ('BldgType_Duplex', -0.093),
#  ('BldgType_TwnhsE', -0.093),
#  ('HouseStyle_2.5Fin', -0.057),
#  ('HouseStyle_2.5Unf', -0.121),
#  ('HouseStyle_SFoyer', 0.021),
#  ('RoofStyle_Gambrel', 0.024),
#  ('RoofMatl_CompShg', 0.07),
#  ('RoofMatl_Membran', 0.033),
#  ('RoofMatl_Metal', 0.006),
#  ('RoofMatl_Roll', 0.002),
#  ('RoofMatl_Tar&Grv', 0.014),
#  ('RoofMatl_WdShake', 0.014),
#  ('RoofMatl_WdShngl', 0.202),
#  ('Exterior1st_AsphShn', -0.003),
#  ('Exterior1st_BrkComm', -0.023),
#  ('Exterior1st_CBlock', -0.006),
#  ('Exterior1st_CemntBd', 0.013),
#  ('Exterior1st_ImStucc', -0.007),
#  ('Exterior1st_Plywood', -0.002),
# ...

# %%
# Double the value of alpha in laso
#Lasso
lm = Lasso(alpha=0.01)
lm.fit(X_train,y_train)

# train score
y_train_pred = lm.predict(X_train)
print(metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

# test score
y_test_pred  = lm.predict(X_test)
print(metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# 0.7758250990657451
# 0.8090417135990562

# %%
sum(lm.coef_==0)
# Out:
# 37

# %%
# Double the value of alpha in laso
#Lasso
lasso = Lasso(alpha=0.02)
lasso.fit(X_train,y_train)

# train score
y_train_pred = lasso.predict(X_train)
print(metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

# test score
y_test_pred  = lm.predict(X_test)
print(metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# 0.7696286097580257
# 0.8000109816264975

# %%
# lasso coefficients
model_parameter = list(lasso.coef_)
model_parameter.insert(0,lasso.intercept_)
model_parameter = [round(x,3) for x in model_parameter]
col = X_train.columns
col = col.insert(0,'Constant')
lasso_02=list(zip(col,model_parameter))

# %%
type(lasso_02)
lasso_02
# Out:
# [('BedroomAbvGr', -0.0),
#  ('BldgType_Duplex', -0.0),
#  ('BldgType_TwnhsE', -0.0),
#  ('BsmtFinSF1', 0.087),
#  ('BsmtQual', 0.054),
#  ('Condition1_Norm', 0.077),
#  ('Condition2_PosN', -0.0),
#  ('Condition2_RRAe', -0.0),
#  ('Constant', -0.146),
#  ('Electrical_FuseP', -0.0),
#  ('Exterior1st_AsphShn', -0.0),
#  ('Exterior1st_BrkComm', -0.0),
#  ('Exterior1st_CBlock', -0.0),
#  ('Exterior1st_CemntBd', 0.0),
#  ('Exterior1st_ImStucc', -0.0),
#  ('Exterior1st_Plywood', -0.0),
#  ('Exterior1st_Stone', 0.0),
#  ('Exterior2nd_AsphShn', -0.0),
#  ('Exterior2nd_CBlock', -0.0),
#  ('Exterior2nd_CmentBd', 0.0),
#  ('Exterior2nd_Stone', 0.0),
#  ('Exterior2nd_Wd Sdng', -0.0),
#  ('Foundation_PConc', 0.092),
#  ('Foundation_Slab', 0.0),
#  ('Functional_Min1', -0.0),
#  ('Functional_Min2', -0.0),
#  ('Functional_Sev', -0.0),
#  ('Functional_Typ', 0.0),
#  ('GarageArea', 0.134),
#  ('GarageType_BuiltIn', 0.0),
#  ('GrLivArea', 0.275),
#  ('Heating_GasA', 0.0),
#  ('Heating_GasW', -0.0),
# ...

# %%
# Double the value of alpha in laso
#Lasso
lasso = Lasso(alpha=0.01)
lasso.fit(X_train,y_train)

# train score
y_train_pred = lasso.predict(X_train)
print(metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

# test score
y_test_pred  = lm.predict(X_test)
print(metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# 0.7758250990657451
# 0.8000109816264975

# %%
# lasso coefficients
model_parameter = list(lasso.coef_)
model_parameter.insert(0,lasso.intercept_)
model_parameter = [round(x,3) for x in model_parameter]
col = X_train.columns
col = col.insert(0,'Constant')
lasso_01=list(zip(col,model_parameter))

# %%
from operator import itemgetter
sorted(lasso_01, key=itemgetter(1),reverse=True)
# Out:
# [('OverallQual', 0.417),
#  ('GrLivArea', 0.294),
#  ('Condition1_Norm', 0.159),
#  ('Foundation_PConc', 0.144),
#  ('GarageArea', 0.134),
#  ('BsmtFinSF1', 0.091),
#  ('TotalBsmtSF', 0.087),
#  ('BsmtQual', 0.079),
#  ('LotArea', 0.062),
#  ('KitchenQual', 0.012),
#  ('Functional_Typ', 0.005),
#  ('Condition2_PosN', -0.0),
#  ('Condition2_RRAe', -0.0),
#  ('BldgType_Duplex', -0.0),
#  ('BldgType_TwnhsE', -0.0),
#  ('HouseStyle_2.5Fin', -0.0),
#  ('HouseStyle_2.5Unf', -0.0),
#  ('HouseStyle_SFoyer', 0.0),
#  ('RoofStyle_Gambrel', 0.0),
#  ('RoofMatl_CompShg', 0.0),
#  ('RoofMatl_Membran', 0.0),
#  ('RoofMatl_Metal', 0.0),
#  ('RoofMatl_Roll', -0.0),
#  ('RoofMatl_Tar&Grv', -0.0),
#  ('RoofMatl_WdShake', 0.0),
#  ('RoofMatl_WdShngl', 0.0),
#  ('Exterior1st_AsphShn', -0.0),
#  ('Exterior1st_BrkComm', -0.0),
#  ('Exterior1st_CBlock', -0.0),
#  ('Exterior1st_CemntBd', 0.0),
#  ('Exterior1st_ImStucc', -0.0),
#  ('Exterior1st_Plywood', -0.0),
#  ('Exterior1st_Stone', 0.0),
# ...

# %%
# Now that we have optimal value of alpha = 20, we can use this alpha to run the model again
#Ridge
ridge = Ridge(alpha=40)
ridge.fit(X_train,y_train)

# train score
y_train_pred = ridge.predict(X_train)
print(metrics.r2_score(y_train, y_train_pred))

# test score
y_test_pred = ridge.predict(X_test)
print(metrics.r2_score(y_test, y_test_pred))
# Out:
# 0.7846128613331366
# 0.8198153134404256

# %%
# ridge coefficients
model_parameter = list(ridge.coef_)
model_parameter.insert(0,ridge.intercept_)
model_parameter = [round(x,3) for x in model_parameter]
col = X_train.columns
col = col.insert(0,'Constant')
list(zip(col,model_parameter))
# Out:
# [('Constant', -0.488),
#  ('LotArea', 0.067),
#  ('OverallQual', 0.384),
#  ('BsmtQual', 0.091),
#  ('BsmtFinSF1', 0.088),
#  ('TotalBsmtSF', 0.099),
#  ('GrLivArea', 0.305),
#  ('BedroomAbvGr', -0.032),
#  ('KitchenQual', 0.033),
#  ('GarageArea', 0.136),
#  ('Condition1_Norm', 0.182),
#  ('Condition2_PosN', -0.105),
#  ('Condition2_RRAe', -0.003),
#  ('BldgType_Duplex', -0.069),
#  ('BldgType_TwnhsE', -0.069),
#  ('HouseStyle_2.5Fin', -0.03),
#  ('HouseStyle_2.5Unf', -0.069),
#  ('HouseStyle_SFoyer', 0.01),
#  ('RoofStyle_Gambrel', 0.013),
#  ('RoofMatl_CompShg', 0.036),
#  ('RoofMatl_Membran', 0.015),
#  ('RoofMatl_Metal', 0.003),
#  ('RoofMatl_Roll', -0.001),
#  ('RoofMatl_Tar&Grv', 0.003),
#  ('RoofMatl_WdShake', 0.005),
#  ('RoofMatl_WdShngl', 0.109),
#  ('Exterior1st_AsphShn', -0.002),
#  ('Exterior1st_BrkComm', -0.014),
#  ('Exterior1st_CBlock', -0.003),
#  ('Exterior1st_CemntBd', 0.016),
#  ('Exterior1st_ImStucc', -0.004),
#  ('Exterior1st_Plywood', -0.006),
# ...

# %%
list_of_variable_to_remove=['OverallQual','GrLivArea','Condition1_Norm','Foundation_PConc','GarageArea']
housing1=housing.drop(list_of_variable_to_remove, axis = 1, inplace = False)

# %%
housing1
# Out:
#       MSSubClass  LotArea  Street  LotShape  Utilities  LandSlope  \
# 0             60     8450       0         0          0          0
# 1             20     9600       0         0          0          0
# 2             60    11250       0         1          0          0
# 3             70     9550       0         1          0          0
# 4             60    14260       0         1          0          0
# ...          ...      ...     ...       ...        ...        ...
# 1455          60     7917       0         0          0          0
# 1456          20    13175       0         0          0          0
# 1457          70     9042       0         0          0          0
# 1458          20     9717       0         0          0          0
# 1459          20     9937       0         0          0          0
#
#       OverallCond  MasVnrArea  ExterQual  ExterCond  ...  Functional_Mod  \
# 0               5       196.0          0          0  ...               0
# ...

# %%
df_train, df_test = train_test_split(housing1, train_size=0.7, test_size=0.3, random_state=100)

# %%
scaler_col = ['MSSubClass','LotArea','OverallCond', 'MasVnrArea','BsmtFinSF1',
              'BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF', 'LowQualFinSF',
              'BsmtFullBath','BsmtHalfBath','FullBath','HalfBath','BedroomAbvGr',
              'KitchenAbvGr','TotRmsAbvGrd','Fireplaces','GarageCars','WoodDeckSF',
              'OpenPorchSF','EnclosedPorch','3SsnPorch', 'ScreenPorch','PoolArea','MiscVal','SalePrice']

scaler = StandardScaler()
df_train[scaler_col] = scaler.fit_transform(df_train[scaler_col])
df_test[scaler_col] = scaler.transform(df_test[scaler_col])

# %%
# Create X and y
y_train = df_train.pop('SalePrice')
X_train = df_train

y_test = df_test.pop('SalePrice')
X_test = df_test

# %%
# RFE
lm  = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm,n_features_to_select=50)
rfe.fit(X_train,y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=50)

# %%
rfe_scores = pd.DataFrame(list(zip(X_train.columns,rfe.support_,rfe.ranking_)))

# %%
rfe_scores
# Out:
#                       0      1   2
# 0            MSSubClass  False  87
# 1               LotArea  False  20
# 2                Street  False  18
# 3              LotShape  False  84
# 4             Utilities  False  23
# ..                  ...    ...  ..
# 139  GarageType_BuiltIn   True   1
# 140  GarageType_CarPort  False  58
# 141   GarageType_Detchd  False  34
# 142        PavedDrive_P  False  93
# 143        PavedDrive_Y  False  33
#
# [144 rows x 3 columns]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['BsmtQual', 'BsmtFinSF1', 'TotalBsmtSF', '2ndFlrSF', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'GarageCars', 'Condition2_Norm',
#        'Condition2_PosA', 'Condition2_PosN', 'Condition2_RRAe',
#        'Condition2_RRNn', 'HouseStyle_1.5Unf', 'HouseStyle_1Story',
#        'HouseStyle_2.5Fin', 'HouseStyle_2.5Unf', 'HouseStyle_SFoyer',
#        'HouseStyle_SLvl', 'RoofMatl_CompShg', 'RoofMatl_Membran',
#        'RoofMatl_Metal', 'RoofMatl_Roll', 'RoofMatl_Tar&Grv',
#        'RoofMatl_WdShake', 'RoofMatl_WdShngl', 'Exterior1st_AsphShn',
#        'Exterior1st_CBlock', 'Exterior1st_CemntBd', 'Exterior1st_ImStucc',
#        'Exterior1st_VinylSd', 'Exterior2nd_AsphShn', 'Exterior2nd_CBlock',
#        'Exterior2nd_CmentBd', 'Exterior2nd_ImStucc', 'Exterior2nd_Stone',
#        'Exterior2nd_VinylSd', 'MasVnrType_Stone', 'Foundation_CBlock',
#        'Foundation_Slab', 'Heating_GasA', 'Heating_GasW', 'Heating_Grav',
# ...

# %%
X_train = X_train[col]
X_test = X_test[col]

# %%
    lm = Lasso(alpha=0.001)
    lm.fit(X_train,y_train)

    # train score
    y_train_pred = lm.predict(X_train)
    print("Train_dataset:",metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

    # test score
    y_test_pred  = lm.predict(X_test)
    print("Test_dataset:",metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# Train_dataset: 0.7739042385767502
# Test_dataset: 0.7446368092933652

# %%
# Gridsearch Operation on Training data set
# Objective - Find optimal value of alpha

folds = KFold(n_splits=10,shuffle=True,random_state=100)

hyper_param = {'alpha':[0.001, 0.01, 0.1,1.0, 5.0, 10.0,20.0]}

model = Lasso()

model_cv = GridSearchCV(estimator = model,
                        param_grid=hyper_param,
                        scoring='r2',
                        cv=folds,
                        verbose=1,
                        return_train_score=True
                       )

model_cv.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 7 candidates, totalling 70 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=100, shuffle=True),
#              estimator=Lasso(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 1.0, 5.0, 10.0, 20.0]},
#              return_train_score=True, scoring='r2', verbose=1)

# %%
cv_result_train_ridge = pd.DataFrame(model_cv.cv_results_)
cv_result_train_ridge['param_alpha'] = cv_result_train_lasso['param_alpha'].astype('float32')
cv_result_train_ridge.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.003211      0.000423         0.001214        0.000430        0.001
# 1       0.001533      0.000885         0.000718        0.000472        0.010
# 2       0.001502      0.002294         0.001000        0.002000        0.100
# 3       0.003021      0.002467         0.000247        0.000740        1.000
# 4       0.002000      0.001000         0.000799        0.000400        5.000
#
#              params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'alpha': 0.001}           0.779521           0.183567           0.785264
# 1   {'alpha': 0.01}           0.752887           0.327903           0.765107
# 2    {'alpha': 0.1}           0.672011           0.390313           0.698044
# 3    {'alpha': 1.0}          -0.010958          -0.010191          -0.000095
# 4    {'alpha': 5.0}          -0.010958          -0.010191          -0.000095
#
# ...

# %%
print('For Lasso, the Best Alpha value = ', model_cv.best_params_['alpha'])
# Out:
# For Lasso, the Best Alpha value =  0.01

# %%
lasso = Lasso(alpha=0.01)
lasso.fit(X_train,y_train)

# train score
y_train_pred = lasso.predict(X_train)
print(metrics.r2_score(y_true=y_train,y_pred=y_train_pred))

# test score
y_test_pred  = lm.predict(X_test)
print(metrics.r2_score(y_true=y_test,y_pred=y_test_pred))
# Out:
# 0.7206323107194745
# 0.7446368092933652

# %%
# lasso coefficients
model_parameter = list(lasso.coef_)
model_parameter.insert(0,lasso.intercept_)
model_parameter = [round(x,3) for x in model_parameter]
col = X_train.columns
col = col.insert(0,'Constant')
lasso_01=list(zip(col,model_parameter))

# %%
from operator import itemgetter
sorted(lasso_01, key=itemgetter(1),reverse=True)
# Out:
# [('TotalBsmtSF', 0.333),
#  ('GarageCars', 0.297),
#  ('GarageType_Attchd', 0.277),
#  ('2ndFlrSF', 0.253),
#  ('TotRmsAbvGrd', 0.221),
#  ('GarageType_BuiltIn', 0.183),
#  ('BsmtFinSF1', 0.099),
#  ('BsmtQual', 0.085),
#  ('HouseStyle_1Story', 0.072),
#  ('Exterior2nd_VinylSd', 0.065),
#  ('Functional_Typ', 0.06),
#  ('Condition2_Norm', 0.0),
#  ('Condition2_PosA', 0.0),
#  ('Condition2_PosN', -0.0),
#  ('Condition2_RRAe', -0.0),
#  ('Condition2_RRNn', 0.0),
#  ('HouseStyle_1.5Unf', 0.0),
#  ('HouseStyle_2.5Fin', -0.0),
#  ('HouseStyle_2.5Unf', -0.0),
#  ('HouseStyle_SFoyer', 0.0),
#  ('HouseStyle_SLvl', 0.0),
#  ('RoofMatl_CompShg', -0.0),
#  ('RoofMatl_Membran', 0.0),
#  ('RoofMatl_Metal', 0.0),
#  ('RoofMatl_Roll', -0.0),
#  ('RoofMatl_Tar&Grv', 0.0),
#  ('RoofMatl_WdShake', 0.0),
#  ('RoofMatl_WdShngl', 0.0),
#  ('Exterior1st_AsphShn', 0.0),
#  ('Exterior1st_CBlock', -0.0),
#  ('Exterior1st_CemntBd', 0.0),
#  ('Exterior1st_ImStucc', 0.0),
#  ('Exterior1st_VinylSd', 0.0),
# ...
